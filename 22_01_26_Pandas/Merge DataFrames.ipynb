# %% [markdown]
# ## Merge Dataframes

# %%
import pandas as pd
import numpy as np

# %%
1. append
2. concat
3. merge
4. join

# %% [markdown]
# ### 1. append

# %%
df.append(df)
df.append([df1,df2,..dfn])

# %%
df1 = pd.DataFrame({'ASCII Value':np.arange(65,70),
                   'Char':[chr(i) for i in range(65,70)]})
df1
# Out:
#    ASCII Value Char
# 0           65    A
# 1           66    B
# 2           67    C
# 3           68    D
# 4           69    E

# %%
df2 = pd.DataFrame({'ASCII Value':np.arange(69,75),
                   'Char':[chr(i) for i in range(69,75)]})
df2
# Out:
#    ASCII Value Char
# 0           69    E
# 1           70    F
# 2           71    G
# 3           72    H
# 4           73    I
# 5           74    J

# %%
df3 = pd.DataFrame({'ASCII Value':np.arange(75,79),
                   'Char':[chr(i) for i in range(75,79)]})
df3
# Out:
#    ASCII Value Char
# 0           75    K
# 1           76    L
# 2           77    M
# 3           78    N

# %%
df1.append(df2) # rows appended
# Out:
#    ASCII Value Char
# 0           65    A
# 1           66    B
# 2           67    C
# 3           68    D
# 4           69    E
# 0           69    E
# 1           70    F
# 2           71    G
# 3           72    H
# 4           73    I
# 5           74    J

# %%
df1.append(df2,ignore_index=True)
# Out:
#     ASCII Value Char
# 0            65    A
# 1            66    B
# 2            67    C
# 3            68    D
# 4            69    E
# 5            69    E
# 6            70    F
# 7            71    G
# 8            72    H
# 9            73    I
# 10           74    J

# %%
df_test = df1.append([df2,df3],ignore_index=True)
df_test
# Out:
#     ASCII Value Char
# 0            65    A
# 1            66    B
# 2            67    C
# 3            68    D
# 4            69    E
# 5            69    E
# 6            70    F
# 7            71    G
# 8            72    H
# 9            73    I
# 10           74    J
# 11           75    K
# 12           76    L
# 13           77    M
# 14           78    N

# %% [markdown]
# ## 2. concat

# %%
df1
# Out:
#    ASCII Value Char
# 0           65    A
# 1           66    B
# 2           67    C
# 3           68    D
# 4           69    E

# %%
df2
# Out:
#    ASCII Value Char
# 0           69    E
# 1           70    F
# 2           71    G
# 3           72    H
# 4           73    I
# 5           74    J

# %%
df3
# Out:
#    ASCII Value Char
# 0           75    K
# 1           76    L
# 2           77    M
# 3           78    N

# %%
pd.concat([df1, df2],ignore_index=True)
# Out:
#     ASCII Value Char
# 0            65    A
# 1            66    B
# 2            67    C
# 3            68    D
# 4            69    E
# 5            69    E
# 6            70    F
# 7            71    G
# 8            72    H
# 9            73    I
# 10           74    J

# %%
pd.concat([df1, df2],ignore_index=True,axis=1)
# Out:
#       0    1   2  3
# 0  65.0    A  69  E
# 1  66.0    B  70  F
# 2  67.0    C  71  G
# 3  68.0    D  72  H
# 4  69.0    E  73  I
# 5   NaN  NaN  74  J

# %%
df2 = pd.DataFrame({'ASCII Value':np.arange(70,75),
                   'Char':[chr(i) for i in range(70,75)]})
df2
# Out:
#    ASCII Value Char
# 0           70    F
# 1           71    G
# 2           72    H
# 3           73    I
# 4           74    J

# %%
df1
# Out:
#    ASCII Value Char
# 0           65    A
# 1           66    B
# 2           67    C
# 3           68    D
# 4           69    E

# %%
df2
# Out:
#    ASCII Value Char
# 0           70    F
# 1           71    G
# 2           72    H
# 3           73    I
# 4           74    J

# %%
pd.concat([df1,df2],axis=1)
# Out:
#    ASCII Value Char  ASCII Value Char
# 0           65    A           70    F
# 1           66    B           71    G
# 2           67    C           72    H
# 3           68    D           73    I
# 4           69    E           74    J

# %%
df1
# Out:
#    ASCII Value Char
# 0           65    A
# 1           66    B
# 2           67    C
# 3           68    D
# 4           69    E

# %%
df2
# Out:
#    ASCII Value Char
# 0           70    F
# 1           71    G
# 2           72    H
# 3           73    I
# 4           74    J

# %%
df2 = df2.head(2)
df2
# Out:
#    ASCII Value Char
# 0           70    F
# 1           71    G

# %%
pd.concat([df1,df2],axis=0,join='inner')
# Out:
#    ASCII Value Char
# 0           65    A
# 1           66    B
# 2           67    C
# 3           68    D
# 4           69    E
# 0           70    F
# 1           71    G

# %%
pd.concat([df1,df2],axis=0,join='outer')
# Out:
#    ASCII Value Char
# 0           65    A
# 1           66    B
# 2           67    C
# 3           68    D
# 4           69    E
# 0           70    F
# 1           71    G

# %%
pd.concat([df1,df2],axis=1,join='inner')
# Out:
#    ASCII Value Char  ASCII Value Char
# 0           65    A           70    F
# 1           66    B           71    G

# %% [markdown]
# ## 3. merge

# %%
how = {'left','right','inner','outer'}
pd.merge(left_df,right_df,how='left')
left_df.merge(right_df,how='left')

# %%
df1
# Out:
#    ASCII Value Char
# 0           65    A
# 1           66    B
# 2           67    C
# 3           68    D
# 4           69    E

# %%
df2 = pd.DataFrame({'ASCII Value':np.arange(68,74),
                   'Char':[chr(i) for i in range(68,74)]})
df2
# Out:
#    ASCII Value Char
# 0           68    D
# 1           69    E
# 2           70    F
# 3           71    G
# 4           72    H
# 5           73    I

# %%
pd.merge(df1,df2,how='inner')
# Out:
#    ASCII Value Char
# 0           68    D
# 1           69    E

# %%
pd.merge(df1,df2,how='inner',on='ASCII Value')
# Out:
#    ASCII Value Char_x Char_y
# 0           68      D      D
# 1           69      E      E

# %%
df4 = pd.DataFrame({'ASCII Value':np.arange(68,74),
                   'Num':[chr(i) for i in range(77,83)]})
df4
# Out:
#    ASCII Value Num
# 0           68   M
# 1           69   N
# 2           70   O
# 3           71   P
# 4           72   Q
# 5           73   R

# %%
df1
# Out:
#    ASCII Value Char
# 0           65    A
# 1           66    B
# 2           67    C
# 3           68    D
# 4           69    E

# %%
pd.merge(df1,df4,how='inner',on='ASCII Value')
# Out:
#    ASCII Value Char Num
# 0           68    D   M
# 1           69    E   N

# %%
a= pd.merge(df1,df2,how='inner',on='ASCII Value')
a
# Out:
#    ASCII Value Char_x Char_y
# 0           68      D      D
# 1           69      E      E

# %%
b= pd.merge(df1,df2,how='inner',on='ASCII Value',suffixes=('_DF1','_DF2'))
b
# Out:
#    ASCII Value Char_DF1 Char_DF2
# 0           68        D        D
# 1           69        E        E

# %%
df1 = pd.DataFrame({'Student_Name':['Mahadev','Pallavi','Dhanraj','Sagar','Amit'],
                   'Maths':[88,79,97,45,68],
                   'Science':[78,65,89,75,76],
                   'Physics':[80,75,65,78,91]})
df1
# Out:
#   Student_Name  Maths  Science  Physics
# 0      Mahadev     88       78       80
# 1      Pallavi     79       65       75
# 2      Dhanraj     97       89       65
# 3        Sagar     45       75       78
# 4         Amit     68       76       91

# %%
df2 = pd.DataFrame({'Student_Name':['Mahadev','Suyog','Dhanraj','Arjun','Monica'],
                   'Chemistry':[77,75,68,69,84],
                   'English':[80,98,81,88,94]})
df2
# Out:
#   Student_Name  Chemistry  English
# 0      Mahadev         77       80
# 1        Suyog         75       98
# 2      Dhanraj         68       81
# 3        Arjun         69       88
# 4       Monica         84       94

# %%
pd.merge(df1,df2,how='inner',on='Student_Name')
# Out:
#   Student_Name  Maths  Science  Physics  Chemistry  English
# 0      Mahadev     88       78       80         77       80
# 1      Dhanraj     97       89       65         68       81

# %%
pd.merge(df1,df2,how='left',on='Student_Name')
# Out:
#   Student_Name  Maths  Science  Physics  Chemistry  English
# 0      Mahadev     88       78       80       77.0     80.0
# 1      Pallavi     79       65       75        NaN      NaN
# 2      Dhanraj     97       89       65       68.0     81.0
# 3        Sagar     45       75       78        NaN      NaN
# 4         Amit     68       76       91        NaN      NaN

# %%
pd.merge(df1,df2,how='right',on='Student_Name')
# Out:
#   Student_Name  Maths  Science  Physics  Chemistry  English
# 0      Mahadev   88.0     78.0     80.0         77       80
# 1        Suyog    NaN      NaN      NaN         75       98
# 2      Dhanraj   97.0     89.0     65.0         68       81
# 3        Arjun    NaN      NaN      NaN         69       88
# 4       Monica    NaN      NaN      NaN         84       94

# %%
pd.merge(df1,df2,how='outer',on='Student_Name')
# Out:
#   Student_Name  Maths  Science  Physics  Chemistry  English
# 0      Mahadev   88.0     78.0     80.0       77.0     80.0
# 1      Pallavi   79.0     65.0     75.0        NaN      NaN
# 2      Dhanraj   97.0     89.0     65.0       68.0     81.0
# 3        Sagar   45.0     75.0     78.0        NaN      NaN
# 4         Amit   68.0     76.0     91.0        NaN      NaN
# 5        Suyog    NaN      NaN      NaN       75.0     98.0
# 6        Arjun    NaN      NaN      NaN       69.0     88.0
# 7       Monica    NaN      NaN      NaN       84.0     94.0

# %%
pd.merge(df1,df2,how='inner') ## use feature name is good practice
# Out:
#   Student_Name  Maths  Science  Physics  Chemistry  English
# 0      Mahadev     88       78       80         77       80
# 1      Dhanraj     97       89       65         68       81

# %%
df1 = pd.DataFrame({'Student_Name':['Mahadev','Pallavi','Dhanraj','Sagar','Amit'],
                   'Maths':[88,79,97,45,68],
                   'Science':[78,65,89,75,76],
                   'Physics':[80,75,65,78,91]})
df1
# Out:
#   Student_Name  Maths  Science  Physics
# 0      Mahadev     88       78       80
# 1      Pallavi     79       65       75
# 2      Dhanraj     97       89       65
# 3        Sagar     45       75       78
# 4         Amit     68       76       91

# %%
df2 = pd.DataFrame({'Student':['Mahadev','Suyog','Dhanraj','Arjun','Monica'],
                   'Chemistry':[77,75,68,69,84],
                   'English':[80,98,81,88,94]})
df2
# Out:
#    Student  Chemistry  English
# 0  Mahadev         77       80
# 1    Suyog         75       98
# 2  Dhanraj         68       81
# 3    Arjun         69       88
# 4   Monica         84       94

# %%
pd.merge(df1,df2,how='inner',left_on='Student_Name',right_on='Student')
# Out:
#   Student_Name  Maths  Science  Physics  Student  Chemistry  English
# 0      Mahadev     88       78       80  Mahadev         77       80
# 1      Dhanraj     97       89       65  Dhanraj         68       81

# %%
pd.merge(df1,df2,how='inner')
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# <ipython-input-42-83e8246936d6> in <module>
# ----> 1 pd.merge(df1,df2,how='inner')
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      72     validate=None,
#      73 ) -> "DataFrame":
# ---> 74     op = _MergeOperation(
#      75         left,
#      76         right,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     648             warnings.warn(msg, UserWarning)
#     649
# --> 650         self._validate_specification()
#     651
#     652         cross_col = None
#
# ...

# %% [markdown]
# ## 4. join

# %%
df1.join(df2,how='left')

# %%
df1 = pd.DataFrame({'A':[10,20,30],'B':[100,200,300]},index = list('abc'))
df1
# Out:
#     A    B
# a  10  100
# b  20  200
# c  30  300

# %%
df2 = pd.DataFrame({'C':[10,20,30],'D':[100,200,300]},index = list('acd'))
df2
# Out:
#     C    D
# a  10  100
# c  20  200
# d  30  300

# %%
df1.join(df2, how='outer')
# Out:
#       A      B     C      D
# a  10.0  100.0  10.0  100.0
# b  20.0  200.0   NaN    NaN
# c  30.0  300.0  20.0  200.0
# d   NaN    NaN  30.0  300.0

# %%
df1.join(df2, how='inner')
# Out:
#     A    B   C    D
# a  10  100  10  100
# c  30  300  20  200

# %%
df1.join(df2, how='left')
# Out:
#     A    B     C      D
# a  10  100  10.0  100.0
# b  20  200   NaN    NaN
# c  30  300  20.0  200.0

# %%
df1.join(df2, how='right')
# Out:
#       A      B   C    D
# a  10.0  100.0  10  100
# c  30.0  300.0  20  200
# d   NaN    NaN  30  300
